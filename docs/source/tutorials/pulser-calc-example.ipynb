# %% [markdown]
# # Calculation Example
#
# The following tutorial shows how to use `qse` to run a calculation.
# We use `pulser` here for the backend.

# %%
import matplotlib.pyplot as plt
import numpy as np
import qse
import pulser

# %% [markdown]
# ## Create a 2D square lattice
#
# Now we generate a qbits object that represents a 2D lattice

# %%
omega_max = 2.0 * 2 * np.pi  # rad/µs
rabi_frequency = omega_max / 2.0  # rad/µs

# Keeping the lattice spacing a bit below the blockade radius keeps
# the nearest neighbours antiferromagnetic.
blockade_radius = qse.calc.blockade_radius(rabi_frequency, pulser.devices.MockDevice.interaction_coeff)
print(f"Blockade radius: {blockade_radius:.2f} µm")

q2d = qse.lattices.square(
    lattice_spacing=0.8 * blockade_radius, repeats_x=3, repeats_y=2
)

q2d.draw(radius="nearest", units="µm")
# Out:
# Blockade radius: 9.76 µm

# %% [markdown]
# ## Create the hamiltonian

# %%
delta_0 = -6 * rabi_frequency  # ns
delta_f = 2 * rabi_frequency  # ns

t_rise = 252  # ns
t_fall = 500  # ns
t_sweep = int((delta_f - delta_0) / (2 * np.pi * 10) * 1000)  # ns
t_total = t_rise + t_sweep + t_fall
print(t_total)
# Out:
# 1552

# %%
amplitude = np.zeros(t_total)
amplitude[:t_rise] = omega_max * np.linspace(0, 1, t_rise)
amplitude[t_rise:-t_fall] = omega_max
amplitude[-t_fall:] = omega_max - omega_max * np.linspace(0, 1, t_fall)
amplitude = qse.Signal(amplitude)

amplitude.draw()

# %%
detuning = np.zeros(t_total)
detuning[:t_rise] = delta_0
detuning[t_rise:-t_fall] = delta_0 + (delta_f-delta_0) * np.linspace(0, 1, t_sweep)
detuning[-t_fall:] = delta_f
detuning = qse.Signal(detuning)

detuning.draw()

# %%
# up ramp, constant, downramp waveform
amplitude_afm = pulser.CompositeWaveform(
    pulser.waveforms.RampWaveform(t_rise, 0.0, omega_max),
    pulser.waveforms.ConstantWaveform(t_sweep, omega_max),
    pulser.waveforms.RampWaveform(t_fall, omega_max, 0.0),
)

# corresponding waveform for detuning
detuning_afm = pulser.CompositeWaveform(
    pulser.waveforms.ConstantWaveform(t_rise, delta_0),
    pulser.waveforms.RampWaveform(t_sweep, delta_0, delta_f),
    pulser.waveforms.ConstantWaveform(t_fall, delta_f),
)

plt.plot(amplitude_afm.samples - amplitude)
plt.plot(detuning_afm.samples - detuning)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.plot(amplitude_afm.samples - amplitude)
#       2 plt.plot(detuning_afm.samples - detuning)
#
# File ~/anaconda3/envs/qse_testbed/lib/python3.12/site-packages/pulser/math/abstract_array.py:235, in AbstractArray.__sub__(self, other)
#     234 def __sub__(self, other: AbstractArrayLike, /) -> AbstractArray:
# --> 235     return AbstractArray(operator.sub(*self._binary_operands(other)))
#
# TypeError: unsupported operand type(s) for -: 'float' and 'Signal'

# %% [markdown]
# ## Set up the calculator and run the job

# %%
pcalc = qse.calc.Pulser(qbits=q2d, amplitude=amplitude, detuning=detuning)
pcalc.build_sequence()
pcalc.calculate()
# Out:
# 10.1%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 60.1%. Run time:   0.01s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.02s. Est. time left: 00:00:00:00
# 100.0%. Run time:   0.02s. Est. time left: 00:00:00:00
# Total run time:   0.02s
# time in compute and simulation = 0.041605234146118164 s.

# %% [markdown]
# ## Sample the result

# %%
count = pcalc.results.sample_final_state()

most_freq = {k: v for k, v in count.items() if v > 10}
plt.bar(list(most_freq.keys()), list(most_freq.values()))
plt.xticks(rotation="vertical")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# The states `011001` and `100110` are the most prevalent, we can visualise them using the `colouring` parameter in `draw`.
# We see that they correspond to anti-ferromagnetic orderings.

# %%
q2d.draw(radius="nearest", colouring="011001", units="µm")

# %%
q2d.draw(radius="nearest", colouring="100110", units="µm")

# %% [markdown]
# ## Version

# %%
qse.utils.print_environment()
# Out:
# Python version: 3.12.12
# qse version: 1.0.3
